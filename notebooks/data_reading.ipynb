# %%
import pandas as pd

# %%
df = pd.read_csv("../data/population/claims/population_claims.csv", header=0)

# %%
len(data)
# Out:
# 49955

# %%
# !wc -l ../data/population/claims/population_claims.csv
# Out:
#    49956 ../data/population/claims/population_claims.csv

# %%
records = df.to_dict(orient='record')

# %%
claim
# Out:
# [{'ObjectID': 'abu dhabi',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 1000230,
#   'SourceID': '0 (68.162.248.83)',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'abu dhabi',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 1850230,
#   'SourceID': '1513217: Mohammedfairouz',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'amsterdam',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 741329,
#   'SourceID': '141597: Ilse@',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'amsterdam',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 742884,
#   'SourceID': '1300620: Krator',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'adelaide',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 1124315,
#   'SourceID': '3922171: Pirate05',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'athens',
#   'PropertyID': 'Population2006',
#   'PropertyValue': 4200000,
#   'SourceID': '1876487: El Greco',
#   'TimeStamp': 'null'},
#  {'ObjectID': 'athens',
# ...
